# %% [markdown]
# <a href="https://colab.research.google.com/github/Meta-Sean/100-ds-problems/blob/master/Alpaca_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install alpaca-trade-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 7.5 MB/s
# ...
#      |████████████████████████████████| 112 kB 47.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 38.1 MB/s
# ...
#      |████████████████████████████████| 299 kB 52.9 MB/s
# ...
#      |████████████████████████████████| 54 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 271 kB 39.4 MB/s
# ...
#      |████████████████████████████████| 144 kB 14.2 MB/s
# ...
#      |████████████████████████████████| 94 kB 2.3 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.4
#     Uninstalling msgpack-1.0.4:
#       Successfully uninstalled msgpack-1.0.4
# ...

# %%
import alpaca_trade_api as alpaca

api = alpaca.REST('PK610EPBC6GIRNK0OJFT', 'r7AlGdRXnBywJSXsI8IuS1P8xU5y0GE4Lm5pBPue', 'https://paper-api.alpaca.markets')

# %%
api.get_account()
# Out:
# Account({   'account_blocked': False,
#     'account_number': 'PA2UYB6V3LLS',
#     'accrued_fees': '0',
#     'buying_power': '200000',
#     'cash': '100000',
#     'created_at': '2019-12-20T17:36:22.510757Z',
#     'crypto_status': 'ACTIVE',
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '0',
#     'equity': '100000',
#     'id': 'f1709190-f241-4a7c-a554-f08b5d911b1a',
#     'initial_margin': '0',
#     'last_equity': '100000',
#     'last_maintenance_margin': '0',
#     'long_market_value': '0',
#     'maintenance_margin': '0',
#     'multiplier': '2',
#     'non_marginable_buying_power': '0',
#     'pattern_day_trader': True,
#     'pending_transfer_in': '0',
#     'portfolio_value': '100000',
#     'regt_buying_power': '200000',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '0',
#     'status': 'ACTIVE',
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
# ...

# %%
api.submit_order('AAPL', side='buy', qty=1, type='market', time_in_force='gtc')
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': 'b0b6dd9d-8b9b-48a9-ba46-b9d54906e415',
#     'canceled_at': None,
#     'client_order_id': '1c3e3aa3-c4f0-4c80-b378-fb082d39545d',
#     'created_at': '2022-06-27T19:24:12.948798068Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '1c60d29f-28af-40b5-9c62-af4731fa2253',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'source': None,
#     'status': 'pending_new',
#     'stop_price': None,
#     'submitted_at': '2022-06-27T19:24:12.947588639Z',
#     'subtag': None,
#     'symbol': 'AAPL',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
# ...

# %%
api.list_positions()
# Out:
# [Position({   'asset_class': 'us_equity',
#      'asset_id': 'b0b6dd9d-8b9b-48a9-ba46-b9d54906e415',
#      'asset_marginable': True,
#      'avg_entry_price': '141.67',
#      'change_today': '0.0002117746717493',
#      'cost_basis': '141.67',
#      'current_price': '141.69',
#      'exchange': 'NASDAQ',
#      'lastday_price': '141.66',
#      'market_value': '141.69',
#      'qty': '1',
#      'qty_available': '1',
#      'side': 'long',
#      'symbol': 'AAPL',
#      'unrealized_intraday_pl': '0.02',
#      'unrealized_intraday_plpc': '0.0001411731488671',
#      'unrealized_pl': '0.02',
#      'unrealized_plpc': '0.0001411731488671'})]

# %%
api.get_bars(symbol='AAPL', timeframe='1Day', limit=10).df
# Out:
#                             open    high     low   close    volume  \
# timestamp
# 2022-06-27 04:00:00+00:00  142.7  143.49  141.09  141.69  49404952
#
#                            trade_count        vwap
# timestamp
# 2022-06-27 04:00:00+00:00       446946  142.243817

# %%
import plotly.graph_objects as go

df = api.get_bars(symbol="AAPL", start="2022-06-23",end="2022-06-23", timeframe="1Min").df
fig = go.Figure(data=[go.Candlestick(x=df.index,
                                     open=df['open'],
                                     high=df['high'],
                                     low=df['low'],
                                     close=df['close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
